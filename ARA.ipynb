# %% [markdown]
# Title: Approximation from shift-invariant spaces with smooth generators
#
# Authors: A Antony selvan, Ayush Bhandari, and R Radha

# %%
import scipy.io
import pandas as pd
data = pd.read_csv('ARA.csv')
data
# Out:
#       digitized  tdigitized
# 0           0.0      -5.000
# 1           0.0      -4.995
# 2           0.0      -4.990
# 3           0.0      -4.985
# 4           0.0      -4.980
# ...         ...         ...
# 1995        0.0       4.975
# 1996        0.0       4.980
# 1997        0.0       4.985
# 1998        0.0       4.990
# 1999        0.0       4.995
#
# [2000 rows x 2 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
t = data.tdigitized;
f = 2 * np.exp(-t**2 / 4) * np.sin(2 * np.pi * t)
plt.plot(data.tdigitized, data.digitized, label='Hardware')
plt.plot(t, f, '--', label='Simulation')
plt.legend()
#plt.xlabel('Time')
#plt.ylabel('Amplitude')
#plt.title('Comparison of Hardware and Simulation')
#plt.grid(True)
plt.show()
